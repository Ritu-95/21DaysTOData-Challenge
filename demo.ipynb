# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritu-95/DataAnalyst/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('data_district_crime.xlsx')
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD        BORO_NM         CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   831526991           67       BROOKLYN  2018-03-31 00:00:00     23:30:00
# 1   496736340          120  STATEN ISLAND  2018-03-31 00:00:00     23:20:00
# 2   399593692          105         QUEENS  2018-03-31 00:00:00     23:15:00
# 3   282376455          110         QUEENS  2018-03-31 00:00:00     23:10:00
# 4   201598299           78       BROOKLYN  2018-03-31 00:00:00     23:10:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD         HADEVELOPT  HOUSING_PSA  \
# 0   2018-03-31     23:37:00        COMPLETED                NaN          NaN
# 1   2018-03-31     23:30:00        COMPLETED   RICHMOND TERRACE      10143.0
# 2   2018-03-31     23:20:00        COMPLETED                NaN          NaN
# 3   2018-03-31     23:20:00        COMPLETED                NaN          NaN
# 4   2018-03-31     23:19:00        COMPLETED  572 WARREN STREET       2379.0
#
# ...

# %%
df.describe()
# Out:
#          CMPLNT_NUM    ADDR_PCT_CD   HOUSING_PSA  JURISDICTION_CODE  \
# count  1.095430e+05  109543.000000   8981.000000      109486.000000
# mean   5.485759e+08      62.203710   6740.281817           0.991953
# std    2.602368e+08      34.478829  14318.362695           8.356367
# min    1.000032e+08       1.000000    218.000000           0.000000
# 25%    3.221076e+08      34.000000    477.000000           0.000000
# 50%    5.482238e+08      62.000000    696.000000           0.000000
# 75%    7.740450e+08      90.000000   1233.000000           0.000000
# max    9.999894e+08     123.000000  66871.000000          97.000000
#
#                KY_CD          PD_CD  TRANSIT_DISTRICT    X_COORD_CD  \
# count  109543.000000  109486.000000       3132.000000  1.095410e+05
# mean      304.255087     412.556939         12.491699  1.004689e+06
# std       153.408398     220.627606         12.194563  2.107122e+04
# min       101.000000     101.000000          1.000000  9.135120e+05
# ...

# %%
df[['CMPLNT_TO_DT','BORO_NM']]
# Out:
#        CMPLNT_TO_DT        BORO_NM
# 0        2018-03-31       BROOKLYN
# 1        2018-03-31  STATEN ISLAND
# 2        2018-03-31         QUEENS
# 3        2018-03-31         QUEENS
# 4        2018-03-31       BROOKLYN
# ...             ...            ...
# 109538   2017-12-28      MANHATTAN
# 109539   2018-01-01         QUEENS
# 109540   2018-01-01      MANHATTAN
# 109541   2018-01-01      MANHATTAN
# 109542   2018-01-01          BRONX
#
# [109543 rows x 2 columns]

# %%
df.loc[10:15]
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD        BORO_NM         CMPLNT_FR_DT CMPLNT_FR_TM  \
# 10   739194437          108         QUEENS  2018-03-31 00:00:00     22:50:00
# 11   479291262          120  STATEN ISLAND  2018-03-31 00:00:00     22:50:00
# 12   752318738           40          BRONX  2018-03-31 00:00:00     22:45:00
# 13   592240589          113         QUEENS  2018-03-31 00:00:00     22:40:00
# 14   171435997           43          BRONX  2018-03-31 00:00:00     22:40:00
# 15   205920890          114         QUEENS  2018-03-31 00:00:00     22:30:00
#
#    CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD       HADEVELOPT  HOUSING_PSA  \
# 10   2018-03-31     23:00:00        COMPLETED              NaN          NaN
# 11   2018-03-31     23:00:00        COMPLETED  WEST BRIGHTON I      10160.0
# 12   2018-03-31     23:00:00        COMPLETED              NaN        811.0
# 13   2018-03-31     22:45:00        COMPLETED              NaN          NaN
# ...

# %%
len(df)
# Out:
# 109543

# %%
df[df['BORO_NM']=='BROOKLYN']
# Out:
#         CMPLNT_NUM  ADDR_PCT_CD   BORO_NM         CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0        831526991           67  BROOKLYN  2018-03-31 00:00:00     23:30:00
# 4        201598299           78  BROOKLYN  2018-03-31 00:00:00     23:10:00
# 5        513742569           88  BROOKLYN  2018-03-31 00:00:00     22:58:00
# 18       401613518           68  BROOKLYN  2018-03-31 00:00:00     22:15:00
# 21       149230249           75  BROOKLYN  2018-03-31 00:00:00     22:15:00
# ...            ...          ...       ...                  ...          ...
# 109528   455382765           71  BROOKLYN  2017-09-01 00:00:00     18:00:00
# 109530   632120479           60  BROOKLYN  2017-05-03 00:00:00     12:00:00
# 109531   756498047           90  BROOKLYN  2017-01-08 00:00:00     00:01:00
# 109533   867281571           79  BROOKLYN  2017-01-01 00:00:00     21:05:00
# 109537   271487603           79  BROOKLYN  2016-09-27 00:00:00     00:01:00
#
# ...

# %%
df['BORO_NM'].value_counts()
# Out:
# BROOKLYN         32222
# MANHATTAN        27445
# BRONX            24322
# QUEENS           20653
# STATEN ISLAND     4843
# Name: BORO_NM, dtype: int64

# %%
df.columns
# Out:
# Index(['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
#        'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'HADEVELOPT',
#        'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD',
#        'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PARKS_NM', 'PATROL_BORO', 'PD_CD',
#        'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'STATION_NAME', 'SUSP_AGE_GROUP',
#        'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT', 'VIC_AGE_GROUP',
#        'VIC_RACE', 'VIC_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude',
#        'Longitude', 'Lat_Lon'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109543 entries, 0 to 109542
# Data columns (total 35 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CMPLNT_NUM         109543 non-null  int64
#  1   ADDR_PCT_CD        109543 non-null  int64
#  2   BORO_NM            109485 non-null  object
#  3   CMPLNT_FR_DT       109543 non-null  object
#  4   CMPLNT_FR_TM       109543 non-null  object
#  5   CMPLNT_TO_DT       93527 non-null   datetime64[ns]
#  6   CMPLNT_TO_TM       93577 non-null   object
#  7   CRM_ATPT_CPTD_CD   109543 non-null  object
#  8   HADEVELOPT         5822 non-null    object
#  9   HOUSING_PSA        8981 non-null    float64
#  10  JURISDICTION_CODE  109486 non-null  float64
#  11  JURIS_DESC         109543 non-null  object
#  12  KY_CD              109543 non-null  int64
#  13  LAW_CAT_CD         109543 non-null  object
#  14  LOC_OF_OCCUR_DESC  90151 non-null   object
# ...

# %%
df['month'] = df['CMPLNT_TO_DT'].dt.month
df.head(10)
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD        BORO_NM         CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   831526991           67       BROOKLYN  2018-03-31 00:00:00     23:30:00
# 1   496736340          120  STATEN ISLAND  2018-03-31 00:00:00     23:20:00
# 2   399593692          105         QUEENS  2018-03-31 00:00:00     23:15:00
# 3   282376455          110         QUEENS  2018-03-31 00:00:00     23:10:00
# 4   201598299           78       BROOKLYN  2018-03-31 00:00:00     23:10:00
# 5   513742569           88       BROOKLYN  2018-03-31 00:00:00     22:58:00
# 6   697659685           52          BRONX  2018-03-31 00:00:00     22:55:00
# 7   865326510          103         QUEENS  2018-03-31 00:00:00     22:53:00
# 8   422569603          120  STATEN ISLAND  2018-03-31 00:00:00     22:50:00
# 9   510371754           42          BRONX  2018-03-31 00:00:00     22:50:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD         HADEVELOPT  HOUSING_PSA  \
# ...

# %%
df['month'].value_counts()
# Out:
# 1.0     31230
# 3.0     30242
# 2.0     29301
# 12.0     1580
# 11.0      434
# 10.0      226
# 9.0       167
# 7.0        91
# 8.0        87
# 6.0        78
# 4.0        46
# 5.0        45
# Name: month, dtype: int64

# %%
df['day of the week'] = df['CMPLNT_TO_DT'].dt.day_name()

# %%
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD        BORO_NM         CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   831526991           67       BROOKLYN  2018-03-31 00:00:00     23:30:00
# 1   496736340          120  STATEN ISLAND  2018-03-31 00:00:00     23:20:00
# 2   399593692          105         QUEENS  2018-03-31 00:00:00     23:15:00
# 3   282376455          110         QUEENS  2018-03-31 00:00:00     23:10:00
# 4   201598299           78       BROOKLYN  2018-03-31 00:00:00     23:10:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD         HADEVELOPT  HOUSING_PSA  \
# 0   2018-03-31     23:37:00        COMPLETED                NaN          NaN
# 1   2018-03-31     23:30:00        COMPLETED   RICHMOND TERRACE      10143.0
# 2   2018-03-31     23:20:00        COMPLETED                NaN          NaN
# 3   2018-03-31     23:20:00        COMPLETED                NaN          NaN
# 4   2018-03-31     23:19:00        COMPLETED  572 WARREN STREET       2379.0
#
# ...

# %%
df['day of the week'].value_counts()
# Out:
# Friday       14026
# Tuesday      13693
# Thursday     13662
# Saturday     13471
# Monday       13430
# Wednesday    13384
# Sunday       11861
# Name: day of the week, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(data=df,x = 'BORO_NM')

# %%
sns.countplot(data = df,x='day of the week')

# %%
sns.countplot(data = df,x = 'month')

# %%
df['month_n'] = df['CMPLNT_TO_DT'].dt.month_name

# %%
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD        BORO_NM         CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   831526991           67       BROOKLYN  2018-03-31 00:00:00     23:30:00
# 1   496736340          120  STATEN ISLAND  2018-03-31 00:00:00     23:20:00
# 2   399593692          105         QUEENS  2018-03-31 00:00:00     23:15:00
# 3   282376455          110         QUEENS  2018-03-31 00:00:00     23:10:00
# 4   201598299           78       BROOKLYN  2018-03-31 00:00:00     23:10:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD         HADEVELOPT  HOUSING_PSA  \
# 0   2018-03-31     23:37:00        COMPLETED                NaN          NaN
# 1   2018-03-31     23:30:00        COMPLETED   RICHMOND TERRACE      10143.0
# 2   2018-03-31     23:20:00        COMPLETED                NaN          NaN
# 3   2018-03-31     23:20:00        COMPLETED                NaN          NaN
# 4   2018-03-31     23:19:00        COMPLETED  572 WARREN STREET       2379.0
#
# ...

# %%
sns.scatterplot(data = df, x= 'Longitude',y ='Latitude', hue = 'LAW_CAT_CD',style = 'LAW_CAT_CD')
